# %% [markdown]
# <a href="https://colab.research.google.com/github/kowais915/deep-learning-416/blob/main/Q2_assignment1_2019249.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv(r'/content/test.csv', header=None)
df_test
# Out:
#        0           1         2            3        4       5      6   \
# 0      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley
# 1    1260          20        RL           65     9750    Pave    NaN
# 2    1261          60        RL          NaN    24682    Pave    NaN
# 3    1262          20        RL           80     9600    Pave    NaN
# 4    1263          50        RL          NaN    11250    Pave    NaN
# ..    ...         ...       ...          ...      ...     ...    ...
# 197  1456          60        RL           62     7917    Pave    NaN
# 198  1457          20        RL           85    13175    Pave    NaN
# 199  1458          70        RL           66     9042    Pave    NaN
# 200  1459          20        RL           68     9717    Pave    NaN
# 201  1460          20        RL           75     9937    Pave    NaN
#
#            7            8          9   ...           70        71      72  \
# 0    LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC
# 1         Reg          Lvl     AllPub  ...           80         0     NaN
# 2         IR3          Lvl     AllPub  ...            0         0     NaN
# 3         Reg          Lvl     AllPub  ...            0         0     NaN
# 4         Reg          Lvl     AllPub  ...            0         0     NaN
# ..        ...          ...        ...  ...          ...       ...     ...
# 197       Reg          Lvl     AllPub  ...            0         0     NaN
# 198       Reg          Lvl     AllPub  ...            0         0     NaN
# 199       Reg          Lvl     AllPub  ...            0         0     NaN
# 200       Reg          Lvl     AllPub  ...            0         0     NaN
# 201       Reg          Lvl     AllPub  ...            0         0     NaN
#
#         73           74       75      76      77        78             79
# 0    Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 1      NaN          NaN        0       7    2008        WD         Normal
# 2      NaN          NaN        0       6    2009        WD         Normal
# 3      NaN          NaN        0       6    2009        WD         Normal
# 4      NaN          NaN        0      11    2009        WD         Normal
# ..     ...          ...      ...     ...     ...       ...            ...
# 197    NaN          NaN        0       8    2007        WD         Normal
# 198  MnPrv          NaN        0       2    2010        WD         Normal
# 199  GdPrv         Shed     2500       5    2010        WD         Normal
# 200    NaN          NaN        0       4    2010        WD         Normal
# 201    NaN          NaN        0       6    2008        WD         Normal
#
# [202 rows x 80 columns]
